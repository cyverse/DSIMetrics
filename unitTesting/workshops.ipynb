# %%
import pandas as pd
from datetime import datetime, time
import requests
from bs4 import BeautifulSoup
import re
pd.set_option('display.max_rows', 10000)

# %%
#Series ID is a simple id to differential duplicate Series Names if they occur more than once a week or repeat during a different semester
#Series Name is the name of the workshop as listed in the Qualtrics form
#The Start Time is the start time of the workshop in 24 hour format
#The End Time is the time of the end of the workshop listed in 24 hour format
#Day of the week tells what day Monday-Sunday the workshop took place, with Monday being 0 and Sunday being 6
seriesList = [[1, 'Data Engineering', 'https://datascience.arizona.edu/events/navigating-world-data-engineering', time(14, 0, 0), time(15,0,0), 'SP', '2024'],
                [2, 'NextGen Geospatial Data Science', 'https://datascience.arizona.edu/events/nextgen-geospatial-data-science', time(14, 0, 0), time(15,0,0), 'SP', '2024'],
                [3, 'Intro To Data Science', 'https://datascience.arizona.edu/events/data-science-essentials-jupyter-ai-tools', time(15, 0, 0), time(16,0,0), 'SP', '2024'],
                [4, 'Cracking The Coding Interview', 'https://datascience.arizona.edu/events/cracking-coding-interview', time(16, 0, 0), time(17,0,0), 'SP', '2024'],
                [5, 'Data Science Tapas', 'https://datascience.arizona.edu/events/data-science-tapas-savor-tools-data-mastery', time(13, 0, 0), time(14,0,0), 'SP', '2024'],
                [6, 'Classical Machine Learning', 'https://datascience.arizona.edu/events/mastering-machine-learning-your-path-data-driven-research', time(14, 0, 0), time(15,0,0), 'SP', '2024'],
                [7, 'Intro to Deep Learning', 'https://datascience.arizona.edu/events/introduction-deep-learning', time(15, 0, 0), time(16,0,0), 'SP', '2024']
                ]
series = pd.DataFrame(seriesList, columns = ['SeriesID', 'Series Name', 'URL', 'Start Time', 'End Time', 'Semester', 'Year'])

# %%
def scrapeWorkshops(url, seriesName):
    response = requests.get(url)
    if (response.status_code == 200):
        soup = BeautifulSoup(response.content, "html.parser")
        
        #Finds all instances of a paragraph with the word 'Topic" in the header of the paragraph
        results = soup.find_all(lambda tag: tag.name == 'p' and any(text in tag.get_text() for text in ['Topic']))
        
        data = []

        if (len(results) != 0):
            spans = results[0].find_all('span')
            
            #Sometimes the header is disconnected from the main list so we need the next element
            if (len(spans) == 1):
                results = results[0].findNext('p')
                spans = results.find_all('span')
            else:
                #Remove the first element since its the header 'Topic"
                spans.pop(0)
            
            i = 0
            year = datetime.now().year

            while i < len(spans):
                temp = []
                text = spans[i].get_text().strip()

                #isName = re.findall(r'^[A-Za-z\s]+$', text) #Finds if a line contains just a name and no date

                #Checks if the next element is a 'c-mrkdwn__tab' and skips it if so
                try:
                    attrs = spans[i+1].attrs
                    if (len(attrs) != 0) and attrs["class"][0] == 'c-mrkdwn__tab':
                        i += 1
                except:
                    pass

                #Checks to see if the element is a date in the format mm/dd
                if re.findall(r'^\d{1,2}/\d{1,2}$', text):
                    date = text + '/' + str(year)
                    temp.append(datetime.strptime(date, '%m/%d/%Y'))
                    temp.append(spans[i+1].get_text().strip())
                    i += 1
                elif re.findall(r'^\d{1,2}/\d{1,2}:$', text):
                    date = text + '/' + str(year)
                    temp.append(datetime.strptime(date, '%m/%d/%Y:'))
                    temp.append(spans[i+1].get_text().strip())
                    i += 1
                elif re.findall(r'^\d{1,2}/\d{1,2}/\d{1,2}$', text):
                    temp.append(datetime.strptime(text, '%m/%d/%y'))
                    temp.append(spans[i+1].get_text().strip())
                    i += 1
                elif re.findall(r'^\d{1,2}/\d{1,2}/\d{1,2}:$', text):
                    temp.append(datetime.strptime(text, '%m/%d/%y:'))
                    temp.append(spans[i+1].get_text().strip())
                    i += 1
                #If neither of those, then the date and name are in the same span and need to be split
                else:
                    split_content = text.split(maxsplit=1)
                    #Checks the format of the date mm/dd
                    if re.findall(r'^\d{1,2}/\d{1,2}$', split_content[0]): 
                        date = split_content[0] + '/' + str(year)
                        temp.append(datetime.strptime(date, '%m/%d/%Y'))
                    elif re.findall(r'^\d{1,2}/\d{1,2}:$', split_content[0]): 
                        date = split_content[0] + '/' + str(year)
                        temp.append(datetime.strptime(date, '%m/%d/%Y:'))
                    #Checks to see if the format of the date is mm/dd/yy
                    elif re.findall(r'^\d{1,2}/\d{1,2}/\d{1,2}$', split_content[0]):
                        temp.append(datetime.strptime(split_content[0], '%m/%d/%y'))
                    elif re.findall(r'^\d{1,2}/\d{1,2}/\d{1,2}:$', split_content[0]):
                        temp.append(datetime.strptime(split_content[0], '%m/%d/%y:'))

                    try:
                        temp.append(split_content[1])
                    except IndexError:
                        temp.append(None)
                    
                data.append(temp)
                i += 1
        else:
            results = soup.find(lambda tag: tag.name == 'h2' and any(text in tag.get_text() for text in ['When'])).findNext('div')
            results.contents.pop(0)
            data = []
            for i in range(0, len(results.contents), 2):
                temp = []
                date = results.contents[i].get_text().strip().split(', ', maxsplit=1)[1]
                for fmt in ('%b. %d, %Y', '%B %d, %Y'):
                    try:
                        temp.append(datetime.strptime(date, fmt))
                    except ValueError:
                        pass
                temp.append(seriesName)
                data.append(temp)
        
        return pd.DataFrame(data, columns = ['Date', 'Workshop Name'])
    else:
        return None

# %%
workshops = pd.DataFrame()

for i in range(len(series)):
    tempDF = scrapeWorkshops(series.loc[i, "URL"], series.loc[i, "Series Name"])
    tempDF['SeriesID'] = series.loc[i, "SeriesID"]
    tempList = [workshops, tempDF]
    workshops = pd.concat(tempList)

# %%
workshops
# Out:
#          Date                                      Workshop Name  SeriesID
# 0  2024-01-29  Building Python based webapps with Streamlit a...         1
# 1  2024-02-05  Deploying ML models and creating demos with St...         1
# 2  2024-02-12  Introduction to SQL Part-1 (Basic Commands and...         1
# 3  2024-02-19  Introduction to SQL Part-2 (Functions, Sub-que...         1
# 4  2024-02-26  Introduction to noSQL Part-1 (Types of noSQL D...         1
# 5  2024-03-04                            Spring Break (No Class)         1
# 6  2024-03-11  Introduction to noSQL Part-2 (Basics of Cassan...         1
# 7  2024-03-18  Introduction to Spark and Hadoop Part-1 (Hadoo...         1
# 8  2024-03-25  Introduction to Spark and Hadoop Part-2 (Intro...         1
# 0  2024-01-16                               Geospatial Data APIs         2
# 1  2024-01-23               Python Data Formats: Raster & Vector         2
# 2  2024-01-30                     Python Visualization Libraries         2
# 3  2024-02-06                              Intro to Cloud Native         2
# 4  2024-02-13                           Cloud Optimized Geotiffs         2
# 5  2024-02-20                       Cloud Optimized Point Clouds         2
# 6  2024-02-27                                      Xarray & Zarr         2
# 7  2024-03-05                                       Spring Break         2
# 8  2024-03-12                      SpatioTemporal Asset Catalogs         2
# 9  2024-03-19                                Google Earth Engine         2
# 10 2024-03-26                           Planet Satellite Imagery         2
# 11 2024-04-02                       Microsoft Planetary Computer         2
# 12 2024-04-09                                       OpenDroneMap         2
# 13 2024-04-16                             Drone Imagery Analysis         2
# 14 2024-04-23                            Containerized Pipelines         2
# 0  2024-01-16                  Introduction to Jupyter Notebooks         3
# 1  2024-01-23               Data Wrangling 101: Pandas in Action         3
# 2  2024-01-30               A Probability & Statistics refresher         3
# 3  2024-02-06               A Probability & Statistics refresher         3
# 4  2024-02-13           Data Visualization Libraries: Matplotlib         3
# 5  2024-02-20              Data Visualization Libraries: Seaborn         3
# 6  2024-02-27                          Exploratory Data Analysis         3
# 7  2024-03-05                         Spring break (No workshop)         3
# 8  2024-03-12                               Time Series Analysis         3
# 9  2024-03-19                            Time Series Forecasting         3
# 10 2024-03-26                 Machine Learning with Scikit-Learn         3
# 11 2024-04-02                        Natural Language Processing         3
# 12 2024-04-09                                      Deep Learning         3
# 13 2024-04-16                                 Prompt Engineering         3
# 14 2024-04-23                                 AI Tools Landscape         3
# 0  2024-02-07                      Cracking The Coding Interview         4
# 1  2024-02-09                      Cracking The Coding Interview         4
# 2  2024-02-12                      Cracking The Coding Interview         4
# 3  2024-02-14                      Cracking The Coding Interview         4
# 4  2024-02-16                      Cracking The Coding Interview         4
# 5  2024-02-19                      Cracking The Coding Interview         4
# 6  2024-02-21                      Cracking The Coding Interview         4
# 7  2024-02-23                      Cracking The Coding Interview         4
# 8  2024-02-26                      Cracking The Coding Interview         4
# 9  2024-02-28                      Cracking The Coding Interview         4
# 10 2024-03-01                      Cracking The Coding Interview         4
# 11 2024-03-04                      Cracking The Coding Interview         4
# 12 2024-03-06                      Cracking The Coding Interview         4
# 13 2024-03-08                      Cracking The Coding Interview         4
# 14 2024-03-11                      Cracking The Coding Interview         4
# 15 2024-03-13                      Cracking The Coding Interview         4
# 16 2024-03-15                      Cracking The Coding Interview         4
# 17 2024-03-18                      Cracking The Coding Interview         4
# 18 2024-03-20                      Cracking The Coding Interview         4
# 19 2024-03-22                      Cracking The Coding Interview         4
# 20 2024-03-25                      Cracking The Coding Interview         4
# 21 2024-03-27                      Cracking The Coding Interview         4
# 22 2024-03-29                      Cracking The Coding Interview         4
# 23 2024-04-01                      Cracking The Coding Interview         4
# 24 2024-04-03                      Cracking The Coding Interview         4
# 25 2024-04-05                      Cracking The Coding Interview         4
# 26 2024-04-08                      Cracking The Coding Interview         4
# 27 2024-04-10                      Cracking The Coding Interview         4
# 28 2024-04-12                      Cracking The Coding Interview         4
# 29 2024-04-15                      Cracking The Coding Interview         4
# 30 2024-04-17                      Cracking The Coding Interview         4
# 31 2024-04-19                      Cracking The Coding Interview         4
# 32 2024-04-22                      Cracking The Coding Interview         4
# 33 2024-04-24                      Cracking The Coding Interview         4
# 34 2024-04-26                      Cracking The Coding Interview         4
# 0  2024-01-17                                 Data Science Tapas         5
# 1  2024-01-24                                 Data Science Tapas         5
# 2  2024-01-31                                 Data Science Tapas         5
# 3  2024-02-07                                 Data Science Tapas         5
# 4  2024-02-14                                 Data Science Tapas         5
# 5  2024-02-21                                 Data Science Tapas         5
# 6  2024-02-28                                 Data Science Tapas         5
# 7  2024-03-13                                 Data Science Tapas         5
# 8  2024-03-20                                 Data Science Tapas         5
# 9  2024-03-27                                 Data Science Tapas         5
# 10 2024-04-03                                 Data Science Tapas         5
# 11 2024-04-10                                 Data Science Tapas         5
# 12 2024-04-17                                 Data Science Tapas         5
# 13 2024-04-24                                 Data Science Tapas         5
# 0  2024-01-18                              Intro to Scikit-Learn         6
# 1  2024-01-25                    Supervised Learning: Regression         6
# 2  2024-02-01                 Supervised Learning:Classification         6
# 3  2024-02-08    Unsupervised Learning: Dimensionality Reduction         6
# 4  2024-02-15                  Unsupervised Learning: Clustering         6
# 5  2024-02-22                         Ensemble Learning: Bagging         6
# 6  2024-02-29                        Ensemble Learning: Boosting         6
# 7  2024-03-07                         Spring break (No workshop)         6
# 8  2024-03-14                             Reinforcement Learning         6
# 9  2024-03-21                                        Perceptrons         6
# 10 2024-03-28                Convolutional Neural Networks (CNN)         6
# 11 2024-04-04                    Recurrent Neural Networks (RNN)         6
# 12 2024-04-11              Generative Adversarial Networks (GAN)         6
# 13 2024-04-18                                       Autoencoders         6
# 14 2024-04-25                                                LLM         6
# 0  2024-01-18                             Intro to Deep Learning         7
# 1  2024-01-25          Deep Learning fundamental architectures 1         7
# 2  2024-02-01          Deep Learning fundamental architectures 2         7
# 3  2024-02-08             Intro to Natural Language processing 1         7
# 4  2024-02-15             Intro to Natural Language processing 2         7
# 5  2024-02-22                    Applications of deep learning 1         7
# 6  2024-02-29                    Applications of deep learning 2         7
# 7  2024-03-07                                       Spring break         7
# 8  2024-03-14                    Applications of deep learning 3         7
# 9  2024-03-21                    Applications of deep learning 4         7
# 10 2024-03-28                 Image analysis and deep learning 1         7
# 11 2024-04-04                 Image analysis and deep learning 2         7
# 12 2024-04-11                State of the art od Deep Learning 1         7
# 13 2024-04-18                                       Quantum AI 1         7
# 14 2024-04-25                                       Quantum AI 2         7
